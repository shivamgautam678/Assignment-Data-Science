# %%
# Assignment 1 :

# %%
#    Q1.  Explain with an example each when to use a for loop and a while loop.
#    Ans. A for loop is used  when we know the exact number of iterations ywe need to perform.

#   eg.
    numbers = [1, 2, 3, 4, 5]
sum = 0

for num in numbers:
    sum += num

print(sum) 
# Output: 15
  
#      A while loop is used when you need to perform a set of operations repeatedly until a certain condition is met.
#        eg.
        sum = 0
num = 1

while sum < 10:
    sum += num
    num += 1

print(sum) 
# Output: 10

# %%
#    Q2. Write a python program to print the sum and product of the first 10 natural numbers using for
#        and while loop.
#    Ans. 
          # using for loop 

# calculate the sum of first 10 natural numbers
sum = 0
for i in range(1, 11):
    sum += i
print("Sum of first 10 natural numbers: ", sum)
# output= 55

# calculate the product of first 10 natural numbers
product = 1
for i in range(1, 11):
    product *= i
print("Product of first 10 natural numbers: ", product)
# output= 3628800


           # using while loop 
# calculate the sum of first 10 natural numbers
sum = 0
i = 1
while i <= 10:
    sum += i
    i += 1
print("Sum of first 10 natural numbers: ", sum)
# output= 55

# calculate the product of first 10 natural numbers
product = 1
i = 1
while i <= 10:
    product *= i
    i += 1
print("Product of first 10 natural numbers: ", product)output= 
# output= 3628800

# %%
#    Q3. Create a python program to compute the electricity bill for a household.

#        The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
#        unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
#        be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
#        You are required to take the units of electricity consumed in a month from the user as input.
#        Your program must pass this test case: when the unit of electricity consumed by the user in a month is
#        310, the total electricity bill should be 2250.

#        Ans.
units = int(input("Enter the number of units consumed: "))

if units <= 100:
    rate = 4.5
    bill = units * rate
elif units <= 200:
    rate = 6
    bill = 100 * 4.5 + (units - 100) * rate
elif units <= 300:
    rate = 10
    bill = 100 * 4.5 + 100 * 6 + (units - 200) * rate
else:
    rate = 20
    bill = 100 * 4.5 + 100 * 6 + 100 * 10 + (units - 300) * rate

print("Your total electricity bill is: Rs. ", bill)

# output : Your total electricity bill is: Rs.  2250.0

# %%
#    Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
#        number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
#        that list.
#    Ans.

# using for loop
cubes = []
for i in range(1, 101):
    cube = i ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes.append(i)
print(cubes)
# output: [2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 
#        30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 
#        56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 
#        84, 85, 86, 88, 90, 92, 94, 95, 96, 98, 100]

# using while loop
cubes = []
i = 1
while i <= 100:
    cube = i ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes.append(i)
    i += 1
print(cubes)
# output: [2, 4, 5, 6, 8, 10, 12, 14, 15, 16, 18, 20, 22, 24, 25, 26, 28, 
#        30, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 52, 54, 55, 
#        56, 58, 60, 62, 64, 65, 66, 68, 70, 72, 74, 75, 76, 78, 80, 82, 
#        84, 85, 86, 88, 90, 92, 94, 95, 96, 98, 100]

# %%
#   Q5. Write a program to filter count vowels in the below-given string.
#       string = "I want to become a data scientist"
#   Ans.
string = "I want to become a data scientist"
vowels = "aeiouAEIOU"
count = 0

for char in string:
    if char in vowels:
        count += 1

print("The number of vowels in the string is:", count)

# output: The number of vowels in the string is: 12
